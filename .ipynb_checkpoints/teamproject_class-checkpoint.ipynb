# %% [markdown]
# * Selenium에서 데이터의 URL을 수집
#  * elements와 element차이점 구분 주의
#  * 적절한 time.sleep기능을 이용해 너무 빠르거나 느리게 지나치지 않도록 설정

# %%
from selenium.webdriver.support.ui import Select
import time

class HREF_SCRETCHER_DABANG(object):
    
    def __init__(self, dong_lst):
        dong_lst = [i.strip() for i in dong_lst] 
        self.dong_lst = dong_lst
    
    
    def checkout_duplicated(self,fname):
        df = pd.read_csv(fname)
        url = 'https://www.dabangapp.com/room/'
        copy = url + df['id'] 
        copy = set(copy)
        dong_lst = set(self.dong_lst)
        return dong_lst - copy
    
    
    def extract_href(self):
        href_lst = []
        chromedriver = './chromedriver'
        driver = webdriver.Chrome(chromedriver)
        driver.get('https://www.dabangapp.com/search#/map?type=region&id=11140162&position=%7B%22center%22%3A%5B127.01550714548125%2C37.55690177250604%5D%2C%22zoom%22%3A14%7D&filters=%7B%22deposit-range%22%3A%5B0%2C999999%5D%2C%22price-range%22%3A%5B0%2C999999%5D%2C%22room-type%22%3A%5B0%2C1%2C2%2C3%2C4%2C5%5D%2C%22deal-type%22%3A%5B0%2C1%5D%2C%22location%22%3A%5B%5B126.97662584360137%2C37.537813508505565%5D%2C%5B127.05438844736113%2C37.57598514804419%5D%5D%7D&cluster=%7B%22name%22%3A%22%EC%8B%A0%EB%8B%B9%EB%8F%99%22%7D')
        for i in self.dong_lst:
            text_box = driver.find_element_by_xpath("//input[@class='SearchForm-input form-control']")
            text_box.clear()
            address =  i
            address = address.decode('utf8')
            text_box.send_keys(address)
            time.sleep(5)
            try:
                click_box = driver.find_element_by_xpath("//ul[@class='SearchForm-list search-items']/li/span[@class='SearchForm-item name full']")
                text = click_box.text
            except:
                print 'text_error' 
            if text == address:    
                click_box.click() 
            else:
                print 'not match'
                continue    
            time.sleep(3)
            try:
                region_box = driver.find_elements_by_class_name("Room-item")
                for i,room_info in enumerate(region_box):
                    try:
                        link = room_info.find_element_by_tag_name('a')
                        href = link.get_attribute('href')
                        href_lst.append(href)
                    except:
                        print 'no a tag with href'
                
                        
                while True:
                    try:
                        time.sleep(3)
                        next_icon = driver.find_element_by_xpath("//ul[@class='Pagination']//a[@class='Pagination-item Pagination-item--next']")
                        next_icon.click()
                        region_box = driver.find_elements_by_class_name("Room-item")

                        for i,room_info in enumerate(region_box):
                            try:
                                link = room_info.find_element_by_tag_name('a')
                                href = link.get_attribute('href')
                                href_lst.append(href)
                            except:
                                print 'no a tag with href'
                                continue
                        
                    except: 
                        print 'no next icon'
                        break

                    
            
            except:
                print 'Nothing to do'
        driver.quit()
        return href_lst
    def findout_non_finded(self):
        
        chromedriver = './chromedriver'
        driver = webdriver.Chrome(chromedriver)
        driver.get('https://www.dabangapp.com/search#/map?type=region&id=11140162&position=%7B%22center%22%3A%5B127.01550714548125%2C37.55690177250604%5D%2C%22zoom%22%3A14%7D&filters=%7B%22deposit-range%22%3A%5B0%2C999999%5D%2C%22price-range%22%3A%5B0%2C999999%5D%2C%22room-type%22%3A%5B0%2C1%2C2%2C3%2C4%2C5%5D%2C%22deal-type%22%3A%5B0%2C1%5D%2C%22location%22%3A%5B%5B126.97662584360137%2C37.537813508505565%5D%2C%5B127.05438844736113%2C37.57598514804419%5D%5D%7D&cluster=%7B%22name%22%3A%22%EC%8B%A0%EB%8B%B9%EB%8F%99%22%7D')
        for i in self.dong_lst:
            text_box = driver.find_element_by_xpath("//input[@class='SearchForm-input form-control']")
            text_box.clear()
            address =  i
            address = address.decode('utf8')
            text_box.send_keys(address)
            time.sleep(5)
            try:
                click_box = driver.find_element_by_xpath("//ul[@class='SearchForm-list search-items']/li/span[@class='SearchForm-item name full']")
                text = click_box.text
            except:
                print 'text_error' 
            if text == address:    
                click_box.click() 
            else:
                print 'not match', address
                continue    
    
    def extract_final_lst(self):
        href_lst = self.extract_href()
        href_dict = Counter(href_lst)
        final_lst = href_dict.keys()
        self.final_lst = final_lst
        return final_lst
    
    def write_file(self, file_name):
        with open(file_name,'w') as txtfile:
            for i in self.final_lst:
                url = i + ' '
                txtfile.write(url)

# %% [markdown]
# * BeautifulSoup이용한 각각의 url 크롤링
#   * 파일 저장할 때 하나의 row에 한번씩 데이터를 쓰는것보다 한꺼번에 쓰는것이 빠르다.

# %%
from bs4 import BeautifulSoup
import requests
import json
import re
import unicodecsv as csv
from pymongo import MongoClient

class Href_to_data(object):
    def __init__(self,href_lst):
        self.href_lst = href_lst
        def href_to_mongodb(self):
            mongo = MongoClient('ec2-54-149-149-184.us-west-2.compute.amazonaws.com', 27017)
            house_info = mongo.db.house_info
            house_data = []
            for href in self.href_lst:
                web = requests.get(href)
                x = re.search('dabang.web.detail\((.*}})',web.content) 
                jsonform = x.group(1)
                jsonf = json.loads(jsonform)
                housedict = {}
                housedict['loc'] = (jsonf['room']['location'])
                housedict['room_size'] = jsonf['room']['room_size']
                housedict['room_floor'] = jsonf['room']['room_floor']
                housedict['building_floor'] = jsonf['room']['building_floor']
                housedict['elevator'] = jsonf['room']['elevator']
                housedict['parking'] = jsonf['room']['parking']
                housedict['animal'] = jsonf['room']['animal']
                housedict['room_options'] = jsonf['room']['room_options']
                housedict['id'] = jsonf['room']['id']
                if jsonf['room']['maintenance']:
                    mc = jsonf['room']['maintenance_cost']
                else: 
                    mc = 0
                if mc is None: 
                    mc = 0
                deposit = jsonf['room']['price_info'][0][0] 
                if deposit is None: 
                    deposit = 0
                rent = jsonf['room']['price_info'][0][1] 
                if rent is None :
                    rent = 0
                price = deposit + (rent + mc) * 100
                housedict['price'] = price
                house_data.append(housedict)
            house_info.insert_many(house_data)
    
    def href_to_csv(self,fname):
        with open(fname, 'w') as fw:
            writer = csv.writer(fw)
            writer.writerow(['id','loc','room_type','size', 'room_floor','building_floor','parking','elevator'
                         ,'heat_type','animal','aircondition','laundry','bed','desk','closet','tv'
                         ,'shoes','refrigerator','gas','induction','microwave','doar_lock','bidet'
                        ,'price'])
            for href in self.href_lst:
                web = requests.get(href)
                x = re.search("dabang.web.detail\((.*}})",web.content)
                jsonform = x.group(1)
                jsonf = json.loads(jsonform)
                loc = jsonf['room']['location']
                room_type =  jsonf['room']['room_type_str']
                size = jsonf['room']['room_size']
                room_floor = jsonf['room']['room_floor']
                building_floor = jsonf['room']['building_floor']
                elevator = jsonf['room']['elevator']
                parking = jsonf['room']['parking']
                heat_type = jsonf['room']['heating']
                animal = jsonf['room']['animal']
                options = jsonf['room']['room_options']
                room_id = jsonf['room']['id']
                aircondition = 0 in options
                laundry = 1 in options
                bed = 2 in options
                desk = 3 in options
                closet = 4 in options
                tv = 5 in options
                shoes = 6 in options
                refrigerator = 7 in options
                gas = 8 in options
                induction = 9 in options
                microwave = 10 in options
                doar_lock = 11 in options
                bidet = 12 in options
                if jsonf['room']['maintenance']:
                    mc = jsonf['room']['maintenance_cost']
                else: 
                    mc = 0
                if mc is None: 
                    mc = 0
                deposit = jsonf['room']['price_info'][0][0] 
                if deposit is None: 
                    deposit = 0
                rent = jsonf['room']['price_info'][0][1] 
                if rent is None :
                    rent = 0
                price = deposit + (rent + mc) * 100
                data_row = [room_id, loc, room_type, size, room_floor, building_floor, parking,
                                 elevator, heat_type, animal, aircondition, laundry, bed, desk,
                                 closet,tv, shoes, refrigerator, gas,induction, microwave,
                                 doar_lock,bidet,price]
                self.fname = fname
                writer.writerow(data_row)
                
    def csv_to_df(self):
        df = pd.read_csv(self.fname)
        return df

# %%
class Transform_csv(object):
  
    def __init__(self,fname):
        df = pd.read_csv(fname)
        self.df = df
        location=  [re.findall('[0-9.]+',i) for i in  self.df['loc']]
        X= [float(i[0]) for i in location]
        Y = [float(i[1]) for i in location]
        only_loc = np.hstack([np.asarray(X).reshape(-1,1),np.asarray(Y).reshape(-1,1)])
        self.only_loc = only_loc
    park = [[126.8141241,37.5876169], [126.8979808,37.5397924], [126.9939698,37.5102684], [127.0165227,37.5272945], [127.081523,37.5179568]
                 ,[127.1194287,37.5499881],[126.8721985,37.5649224],  [126.8986955,37.555875], [126.9736383,37.5159618], [127.0691564,37.5291008]]

    
    def d_to_park(self):

        def dist_park(x):
            z = []
            for i in range(len(park)):
                k = ((114*(x[0] - park[i][0]))**2 + ((92*(x[1] - park[i][1]))**2))**(1.0/2.0)
                z.append(k)
            return min(z)
        return np.apply_along_axis(dist_park,1,self.only_loc)
        
  

    def d_to_myoungdong(self):
        def dist_myongdong(x):
            k = ((114*(x[0] - 126.9653337))**2 + ((92*(x[1] - 37.5634056))**2))**(1.0/2.0)
            return k
        return np.apply_along_axis(dist_myongdong,1,self.only_loc)
    
    
    def d_to_gangnam(self):    
        def dist_gangnam(x):
            k = ((114*(x[0] - 127.0083444))**2 +(92*(x[1] - 37.5002943))**2)**(1.0/2.0) 
            return k
        return np.apply_along_axis(dist_gangnam,1,self.only_loc)
df = Transform_csv('updated_data_distance.csv')
df.d_to_gangnam()
# Out:
# array([  1.45888367,   1.37086607,   1.06409013, ...,  13.78637769,
#          6.72390009,  13.90658458])

# %%
import re
import numpy as np
df = pd.read_csv('updated_data_distance.csv')
x=  [re.findall('[0-9.]+',i) for i in  df['loc']]
X= [float(i[0]) for i in x]
Y = [float(i[1]) for i in x]
a = np.hstack([np.asarray(X).reshape(-1,1),np.asarray(Y).reshape(-1,1)])
def dist_park(x):
    z = []
    for i in range(len(park)):
        print x[0],x[1]
        k = ((114*(x[0] - park[i][0]))**2 + ((92*(x[1] - park[i][1]))**2))**(1.0/2.0)
        z.append(k)
    return min(z)
#dist_park(X,Y)

# %%
new_url = HREF_SCRETCHER_DABANG(['https://www.dabangapp.com/room/56dcf84d56943026cc32afd0'])

# %%
import pandas as pd

df = pd.read_csv('updated_data_distance.csv')
col = df.columns.tolist()
cols = col[2:4] + col[-1:-4:-1] + col[4:-3]
df = df[cols]
df = df.drop_duplicates('id')
df.describe()
a = '''u'room_type', u'size', u'room_floor', u'building_floor', u'parking',
       u'elevator', u'heat_type', u'animal', u'aircondition', u'laundry',
       u'bed', u'desk', u'closet', u'tv', u'shoes', u'refrigerator', u'gas',
       u'induction', u'microwave', u'doar_lock', u'bidet' '''
x = re.findall('[a-z_]+',a)
j = ''
for i in x: 
    if i =='u':
        continue
    j += i+' ' + '+'

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

#Pf = PolynomialFeatures(2).fit_transform(df.ix[:,2:-1])
sm.OLS(endog = df.price, exog = Pf).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     21.01
# Date:                Fri, 07 Oct 2016   Prob (F-statistic):               0.00
# Time:                        21:41:25   Log-Likelihood:                -23712.
# No. Observations:                2575   AIC:                         4.794e+04
# Df Residuals:                    2316   BIC:                         4.946e+04
# Df Model:                         258
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       3101.7097   1374.406      2.257      0.024       406.516  5796.904
# x1           -39.8028    161.844     -0.246      0.806      -357.177   277.571
# x2          -778.0183    171.560     -4.535      0.000     -1114.446  -441.591
# x3           -90.1158    211.214     -0.427      0.670      -504.304   324.072
# x4           240.3034     21.289     11.288      0.000       198.556   282.051
# x5           627.0423    204.950      3.059      0.002       225.137  1028.947
# x6           272.4614    203.825      1.337      0.181      -127.236   672.159
# x7          -431.3324    491.783     -0.877      0.381     -1395.713   533.048
# x8          1897.0153    552.353      3.434      0.001       813.857  2980.174
# x9           331.8619    536.288      0.619      0.536      -719.792  1383.516
# x10         1571.1480    674.212      2.330      0.020       249.026  2893.270
# x11         2007.5933    836.382      2.400      0.016       367.458  3647.729
# x12        -1868.6355    852.664     -2.192      0.029     -3540.700  -196.571
# x13         -178.1410    919.094     -0.194      0.846     -1980.475  1624.193
# x14        -1675.1942    675.083     -2.481      0.013     -2999.024  -351.365
# x15        -1208.7933   1257.930     -0.961      0.337     -3675.579  1257.993
# x16         1168.2757    501.451      2.330      0.020       184.935  2151.616
# x250       -1120.4148    574.532     -1.950      0.051     -2247.065     6.235
# x251       -1480.8395    664.127     -2.230      0.026     -2783.185  -178.494
# x252        -187.6629    626.993     -0.299      0.765     -1417.189  1041.864
# x253         369.6957    344.870      1.072      0.284      -306.591  1045.982
# x254       -4423.5262   2702.314     -1.637      0.102     -9722.734   875.682
# x255       -1726.6994    856.295     -2.016      0.044     -3405.884   -47.515
# x256        -269.2548    799.245     -0.337      0.736     -1836.565  1298.055
# x257         423.7117    881.229      0.481      0.631     -1304.369  2151.793
# x258       -1488.3672   1168.947     -1.273      0.203     -3780.660   803.926
# x259        -814.9758    580.228     -1.405      0.160     -1952.797   322.846
# x260        3125.2988   2208.958      1.415      0.157     -1206.444  7457.041
# x261         732.1131    554.194      1.321      0.187      -354.654  1818.881
# x262         918.6728    760.723      1.208      0.227      -573.097  2410.442
# x263        -343.2090    790.285     -0.434      0.664     -1892.949  1206.531
# x264        -509.8022    576.860     -0.884      0.377     -1641.018   621.414
# x265       -3174.2929   2599.045     -1.221      0.222     -8270.991  1922.405
# x266        -666.3818    774.096     -0.861      0.389     -2184.376   851.613
# x267         207.8963    838.096      0.248      0.804     -1435.600  1851.393
# x268        -813.8082    631.644     -1.288      0.198     -2052.456   424.839
# x269       -2836.6354   2403.033     -1.180      0.238     -7548.955  1875.685
# x270         534.6557   1049.137      0.510      0.610     -1522.690  2592.001
# x271        -657.3325    505.081     -1.301      0.193     -1647.791   333.126
# x272         418.6833   1907.113      0.220      0.826     -3321.145  4158.511
# x273        2068.8192    511.553      4.044      0.000      1065.669  3071.969
# x274        3851.3109   1858.070      2.073      0.038       207.657  7494.965
# x275        1922.8379   1695.639      1.134      0.257     -1402.292  5247.967
# ==============================================================================
# Omnibus:                      560.657   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2514.739
# Skew:                           0.980   Prob(JB):                         0.00
# Kurtosis:                       7.427   Cond. No.                     2.93e+22
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.36e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
sm.OLS.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-63a6aed6a7b9> in <module>()
# ----> 1 sm.OLS.fit()
#
# TypeError: unbound method fit() must be called with OLS instance as first argument (got nothing instead)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
print df.columns
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
df[[ u'parking',
       u'elevator', u'animal', u'aircondition', u'laundry',
       u'bed', u'desk', u'closet', u'tv', u'shoes', u'refrigerator', u'gas',
       u'induction', u'microwave', u'doar_lock', u'bidet']] = lb.fit_transform(df[[ u'parking',
       u'elevator', u'animal', u'aircondition', u'laundry',
       u'bed', u'desk', u'closet', u'tv', u'shoes', u'refrigerator', u'gas',
       u'induction', u'microwave', u'doar_lock', u'bidet']])

result = sm.OLS.from_formula('''np.log(price)~  + I(distance_gn**2) + distance_gn  + I(distance_md**2) + distance_md + distance_park + 
                             room_type  +parking + elevator
                             +heat_type +animal +aircondition +laundry +bed +desk +closet +tv +shoes
                             +refrigerator +gas +induction +microwave +doar_lock +bidet''',data=df).fit()
print result.summary()
# Out:
# Index([u'id', u'loc', u'distance_gn', u'distance_md', u'distance_park',
#        u'room_type', u'size', u'room_floor', u'building_floor', u'parking',
#        u'elevator', u'heat_type', u'animal', u'aircondition', u'laundry',
#        u'bed', u'desk', u'closet', u'tv', u'shoes', u'refrigerator', u'gas',
#        u'induction', u'microwave', u'doar_lock', u'bidet', u'price'],
#       dtype='object')
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(price)   R-squared:                       0.491
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     94.47
# Date:                Fri, 07 Oct 2016   Prob (F-statistic):               0.00
# Time:                        21:44:26   Log-Likelihood:                -837.41
# No. Observations:                2575   AIC:                             1729.
# Df Residuals:                    2548   BIC:                             1887.
# Df Model:                          26
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------
# Intercept                      9.1147      0.063    144.402      0.000         8.991     9.239
# room_type[T.오피스텔]     -0.0605      0.037     -1.615      0.106        -0.134     0.013
# room_type[T.원룸]           -0.2471      0.024    -10.090      0.000        -0.295    -0.199
# room_type[T.투룸]            0.3666      0.028     13.204      0.000         0.312     0.421
# heat_type[T.중앙 난방]    -0.1123      0.032     -3.544      0.000        -0.174    -0.050
# heat_type[T.지역 난방]     0.1585      0.081      1.947      0.052        -0.001     0.318
# I(distance_gn ** 2)            0.0005      0.000      1.286      0.199        -0.000     0.001
# distance_gn                   -0.0263      0.008     -3.189      0.001        -0.043    -0.010
# I(distance_md ** 2)            0.0023      0.000      7.521      0.000         0.002     0.003
# distance_md                   -0.0367      0.007     -5.383      0.000        -0.050    -0.023
# distance_park                 -0.0387      0.004    -10.275      0.000        -0.046    -0.031
# parking                        0.1127      0.017      6.533      0.000         0.079     0.147
# elevator                       0.1314      0.018      7.390      0.000         0.097     0.166
# animal                        -0.0305      0.025     -1.197      0.232        -0.080     0.019
# aircondition                   0.2408      0.030      8.122      0.000         0.183     0.299
# laundry                       -0.0695      0.032     -2.205      0.028        -0.131    -0.008
# bed                            0.0411      0.019      2.220      0.027         0.005     0.077
# desk                          -0.0677      0.020     -3.304      0.001        -0.108    -0.028
# closet                         0.0306      0.021      1.492      0.136        -0.010     0.071
# tv                            -0.1196      0.026     -4.613      0.000        -0.170    -0.069
# shoes                          0.1185      0.018      6.459      0.000         0.083     0.155
# refrigerator                  -0.1611      0.029     -5.505      0.000        -0.218    -0.104
# gas                           -0.0088      0.025     -0.348      0.728        -0.058     0.041
# induction                      0.0600      0.029      2.037      0.042         0.002     0.118
# microwave                     -0.0761      0.021     -3.698      0.000        -0.117    -0.036
# doar_lock                      0.0921      0.017      5.475      0.000         0.059     0.125
# bidet                          0.1803      0.055      3.292      0.001         0.073     0.288
# ==============================================================================
# Omnibus:                       35.451   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.722
# Skew:                           0.082   Prob(JB):                     1.08e-13
# Kurtosis:                       3.728   Cond. No.                     2.36e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.36e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sm.graphics.plot_leverage_resid2(result)
